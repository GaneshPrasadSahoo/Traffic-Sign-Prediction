# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\Ahead only"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"ahead_{count}.jpg")
  os.rename(source,destination)
  count+=1

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\Beware of icesnow"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"Beware_of_icesnow{count}.jpg")
  os.rename(source,destination)
  count+=1

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\Bicycles crossing"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"Bicyclescrossing_{count}.jpg")
  os.rename(source,destination)
  count+=1

count_img=os.listdir(folder)
gp=len(count_img)
print("total_img in Bicycles_crossing0: ",gp)
# Out:
# total_img in Bicycles_crossing0:  240

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\Bumpy road"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"Bumpy_road{count}.jpg")
  os.rename(source,destination)
  count+=1

count_img=os.listdir(folder)
gp=len(count_img)
print("total_img in Bumpy road: ",gp)
# Out:
# total_img in Bumpy road:  330

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\Children crossing"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"Children_crossing{count}.jpg")
  os.rename(source,destination)
  count+=1

count_img=os.listdir(folder)
gp=len(count_img)
print("total_img in Children crossing road: ",gp)
# Out:
# total_img in Children crossing road:  480

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\Dangerous curve left"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"Dangerous_curve_left{count}.jpg")
  os.rename(source,destination)
  count+=1

count_img=os.listdir(folder)
gp=len(count_img)
print("total_img in Dangerous_curve_left: ",gp)
# Out:
# total_img in Dangerous_curve_left:  180

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\Dangerous curve left"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"Dangerous_curve_left_{count}.jpg")
  os.rename(source,destination)
  count+=1

count_img=os.listdir(folder)
gp=len(count_img)
print("total_img in Dangerous_curve_left: ",gp)
# Out:
# total_img in Dangerous_curve_left:  180

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\Double curve"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"Double_curve{count}.jpg")
  os.rename(source,destination)
  count+=1

count_img=os.listdir(folder)
gp=len(count_img)
print("total_img in Double curve: ",gp)
# Out:
# total_img in Double curve:  270

# %%
folder=r"D:\All_DataSet2\Trafic Sign recognition\Train\End no passing"
count=1
for filename in os.listdir(folder):
  source=os.path.join(folder,filename)
  destination=os.path.join(folder,f"End_no_passing{count}.jpg")
  os.rename(source,destination)
  count+=1

count_img=os.listdir(folder)
gp=len(count_img)
print("total_img in End no passing: ",gp)
# Out:
# total_img in End no passing:  210

# %%
import cv2
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
img_size=150
labels=["Ahead only","Beware of icesnow","Bicycles crossing","Bumpy road","Children crossing","Dangerous curve left","Dangerous curve right","Double curve","End no passing","End of no passing","End of speed limit (80kmh)","End speed + passing limits","General caution","Go straight or left","Go straight or right","Keep left","Keep right","No entry","No passing","No passing veh over 3.5 tons","No vehicles","Pedestrians","Priority road","Right-of-way at intersection","Road narrows on the right","Road work","Roundabout mandatory","Slippery road","Speed limit (20kmh)","Speed limit (30kmh)","Speed limit (50kmh)","Speed limit (60kmh)","Speed limit (70kmh)","Speed limit (80kmh)","Speed limit (100kmh)","Speed limit (120kmh)","Stop","Traffic signals","Turn left ahead","Turn right ahead","Veh  3.5 tons prohibited","Wild animals crossing","Yield"]

x_train=[]
y_train=[]
x_test=[]
y_test=[]


for label in labels:
  folderpath=os.path.join(r"D:\All_DataSet2\Trafic Sign recognition\Train",label) 
  for filename in os.listdir(folderpath):
    img_path=os.path.join(folderpath,filename)
    img=cv2.imread(img_path)

    if img is not None:
      img=cv2.resize(img,(img_size,img_size))
      x_train.append(img)
      y_train.append(label)




#load test data
for label in labels:
  folderpath=os.path.join(r"D:\All_DataSet2\Trafic Sign recognition\Test",label) 
  for filename in os.listdir(folderpath):
    img_path=os.path.join(folderpath,filename)
    img=cv2.imread(img_path)

    if img is not None:
      img=cv2.resize(img,(img_size,img_size))
      x_train.append(img)
      y_train.append(label)


x_train=np.array(x_train)
y_train=np.array(y_train)
x_test=np.array(x_test)
y_test=np.array(y_test)

# %%
from sklearn.utils import shuffle

x_train,y_train=shuffle(x_train,y_train,random_state=100)
x_train.shape
# Out:
# (68542, 150, 150, 3)

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=100)


print("x_train shape:", x_train.shape)
print("x_val shape:", x_val.shape)
print("x_test shape:", x_test.shape)
# Out:
# x_train shape: (43866, 150, 150, 3)
# x_val shape: (10967, 150, 150, 3)
# x_test shape: (0,)

# %%
print("x_train shape after splitting:", x_train.shape)
print("x_val shape after splitting:", x_val.shape)
print("y_train shape after splitting:", len(y_train))
print("y_val shape after splitting:", len(y_val))
# Out:
# x_train shape after splitting: (43866, 150, 150, 3)
# x_val shape after splitting: (10967, 150, 150, 3)
# y_train shape after splitting: 43866
# y_val shape after splitting: 10967

# %%
import tensorflow as tf

y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))  # Convert string labels to integer labels
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)  # Convert integer labels to one-hot encoding

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))  # Convert string labels to integer labels
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)  # Convert integer labels to one-hot encoding
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 5
#       3 y_train_new = []
#       4 for i in y_train:
# ----> 5     y_train_new.append(labels.index(i))  # Convert string labels to integer labels
#       6 y_train = y_train_new
#       7 y_train = tf.keras.utils.to_categorical(y_train)  # Convert integer labels to one-hot encoding
#
# ValueError: 9 is not in list

# %%
print(labels)
print(set(y_train))
print(set(y_test))
# Out:
# ['Ahead only', 'Beware of icesnow', 'Bicycles crossing', 'Bumpy road', 'Children crossing', 'Dangerous curve left', 'Dangerous curve right', 'Double curve', 'End no passing', 'End of no passing', 'End of speed limit (80kmh)', 'End speed + passing limits', 'General caution', 'Go straight or left', 'Go straight or right', 'Keep left', 'Keep right', 'No entry', 'No passing', 'No passing veh over 3.5 tons', 'No vehicles', 'Pedestrians', 'Priority road', 'Right-of-way at intersection', 'Road narrows on the right', 'Road work', 'Roundabout mandatory', 'Slippery road', 'Speed limit (20kmh)', 'Speed limit (30kmh)', 'Speed limit (50kmh)', 'Speed limit (60kmh)', 'Speed limit (70kmh)', 'Speed limit (80kmh)', 'Speed limit (100kmh)', 'Speed limit (120kmh)', 'Stop', 'Traffic signals', 'Turn left ahead', 'Turn right ahead', 'Veh  3.5 tons prohibited', 'Wild animals crossing', 'Yield']
# ...

# %%
# Print the labels list
print("Labels List:", labels)

# Print unique values in y_train
print("Unique Labels in y_train:", set(y_train))

# Print unique values in y_test
print("Unique Labels in y_test:", set(y_test))

# Check for missing labels in the labels list
missing_in_labels_train = set(y_train) - set(labels)
missing_in_labels_test = set(y_test) - set(labels)

if missing_in_labels_train:
    print("Labels in y_train missing from labels list:", missing_in_labels_train)

if missing_in_labels_test:
    print("Labels in y_test missing from labels list:", missing_in_labels_test)
# Out:
# Labels List: ['Ahead only', 'Beware of icesnow', 'Bicycles crossing', 'Bumpy road', 'Children crossing', 'Dangerous curve left', 'Dangerous curve right', 'Double curve', 'End no passing', 'End of no passing', 'End of speed limit (80kmh)', 'End speed + passing limits', 'General caution', 'Go straight or left', 'Go straight or right', 'Keep left', 'Keep right', 'No entry', 'No passing', 'No passing veh over 3.5 tons', 'No vehicles', 'Pedestrians', 'Priority road', 'Right-of-way at intersection', 'Road narrows on the right', 'Road work', 'Roundabout mandatory', 'Slippery road', 'Speed limit (20kmh)', 'Speed limit (30kmh)', 'Speed limit (50kmh)', 'Speed limit (60kmh)', 'Speed limit (70kmh)', 'Speed limit (80kmh)', 'Speed limit (100kmh)', 'Speed limit (120kmh)', 'Stop', 'Traffic signals', 'Turn left ahead', 'Turn right ahead', 'Veh  3.5 tons prohibited', 'Wild animals crossing', 'Yield']
# ...

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=len(labels))
y_test = tf.keras.utils.to_categorical(y_test, num_classes=len(labels))

# %%
import numpy as np

# Convert one-hot encoding to integer labels
y_train_new = np.argmax(y_train, axis=1)  # Extract index of max value for each row
y_test_new = np.argmax(y_test, axis=1)  # Same for test set

# %%
# Convert integer labels back to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=len(labels))
y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=len(labels))

# %%
import tensorflow as tf
import numpy as np

# Step 1: Convert one-hot encoding to integer labels (if needed)
y_train_new = np.argmax(y_train, axis=1)
y_test_new = np.argmax(y_test, axis=1)

# Step 2: Skip the string-to-index conversion; indices are already integers
y_train_indices = y_train_new  # Integer indices
y_test_indices = y_test_new    # Integer indices

# Step 3: Convert integer labels back to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train_indices, num_classes=len(labels))
y_test = tf.keras.utils.to_categorical(y_test_indices, num_classes=len(labels))

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (43866, 43)
# y_test shape: (0, 43)

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into train and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=100)

print(f"x_train shape: {x_train.shape}")
print(f"x_val shape: {x_val.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# x_train shape: (35092, 150, 150, 3)
# x_val shape: (8774, 150, 150, 3)
# y_train shape: (35092, 43)
# y_val shape: (8774, 43)

# %%
import numpy as np
import tensorflow as tf

# Step 1: Convert one-hot encoded labels back to integer labels
y_train_int = np.argmax(y_train, axis=1)  # Decode one-hot labels into integer labels
y_test_int = np.argmax(y_test, axis=1)  # Decode one-hot labels into integer labels

# Step 2: Convert integer labels to class indices (if necessary)
y_train_new = [labels[i] for i in y_train_int]
y_test_new = [labels[i] for i in y_test_int]

# Step 3: Convert back to one-hot encoding (optional, if you need one-hot encoding again)
y_train = tf.keras.utils.to_categorical(y_train_int, num_classes=len(labels))
y_test = tf.keras.utils.to_categorical(y_test_int, num_classes=len(labels))

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (35092, 43)
# y_test shape: (0, 43)

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout
from sklearn.metrics import accuracy_score

import ipywidgets as widgets
import io
from PIL import Image
from sklearn.model_selection import train_test_split
import cv2
from sklearn.utils import shuffle
import tensorflow as tf

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation = 'relu',input_shape=(150,150,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512,activation = 'relu'))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(43,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 146, 146, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 71, 71, 64)     │        36,928 │
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    x_train,            
    y_train,           
    epochs=10,         
    validation_split=0.1,  
    batch_size=32       
)
# Out:
# Epoch 1/10
# 987/987 ━━━━━━━━━━━━━━━━━━━━ 1188s 1s/step - accuracy: 0.2343 - loss: 3.0156 - val_accuracy: 0.9048 - val_loss: 0.3132
# Epoch 2/10
# 987/987 ━━━━━━━━━━━━━━━━━━━━ 1169s 1s/step - accuracy: 0.9071 - loss: 0.3042 - val_accuracy: 0.9624 - val_loss: 0.1135
# Epoch 3/10
# 987/987 ━━━━━━━━━━━━━━━━━━━━ 1276s 1s/step - accuracy: 0.9545 - loss: 0.1529 - val_accuracy: 0.9749 - val_loss: 0.0745
# Epoch 4/10
# 987/987 ━━━━━━━━━━━━━━━━━━━━ 1206s 1s/step - accuracy: 0.9694 - loss: 0.1021 - val_accuracy: 0.9855 - val_loss: 0.0546
# Epoch 5/10
# 987/987 ━━━━━━━━━━━━━━━━━━━━ 1168s 1s/step - accuracy: 0.9785 - loss: 0.0748 - val_accuracy: 0.9729 - val_loss: 0.0893
# Epoch 6/10
# 987/987 ━━━━━━━━━━━━━━━━━━━━ 1167s 1s/step - accuracy: 0.9726 - loss: 0.0919 - val_accuracy: 0.9835 - val_loss: 0.0594
# Epoch 7/10
# 987/987 ━━━━━━━━━━━━━━━━━━━━ 1169s 1s/step - accuracy: 0.9782 - loss: 0.0758 - val_accuracy: 0.9835 - val_loss: 0.0491
# Epoch 8/10
# ...

# %%
acc=history.history["accuracy"]
val_acc = history.history['val_accuracy']
epochs = range(len(acc))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,acc,'r',label="Training Accuracy")
plt.plot(epochs,val_acc,'b',label="Validation Accuracy")
plt.legend(loc='upper left')
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,loss,'r',label="Training loss")
plt.plot(epochs,val_loss,'b',label="Validation loss")
plt.legend(loc='upper left')
plt.show()

# %%
import cv2
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image  # Correct import for image loading
from tensorflow.keras.models import load_model  # To load a pre-trained model

# Define image path
img_path = r"C:\Users\Ganesh prasad sahoo\OneDrive\Desktop\download.jpg"

# Read and preprocess the image
img = cv2.imread(img_path)
img = cv2.resize(img, (150, 150))  
img_array = np.array(img)
img_array = img_array.reshape(1, 150, 150, 3)  # Reshape to add batch dimension

# Load and display the image using matplotlib
img_to_display = image.load_img(img_path)
plt.imshow(img_to_display, interpolation='nearest')
plt.show()


a = model.predict(img_array)  
indices = a.argmax()  

# Labels for the prediction
labels=["Ahead only","Beware of icesnow","Bicycles crossing","Bumpy road","Children crossing","Dangerous curve left","Dangerous curve right","Double curve","End no passing","End of no passing","End of speed limit (80kmh)","End speed + passing limits","General caution","Go straight or left","Go straight or right","Keep left","Keep right","No entry","No passing","No passing veh over 3.5 tons","No vehicles","Pedestrians","Priority road","Right-of-way at intersection","Road narrows on the right","Road work","Roundabout mandatory","Slippery road","Speed limit (20kmh)","Speed limit (30kmh)","Speed limit (50kmh)","Speed limit (60kmh)","Speed limit (70kmh)","Speed limit (80kmh)","Speed limit (100kmh)","Speed limit (120kmh)","Stop","Traffic signals","Turn left ahead","Turn right ahead","Veh  3.5 tons prohibited","Wild animals crossing","Yield"]


# Display the predicted label
predicted_label = labels[indices]
print(f"Predicted Label: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Predicted Label: Slippery road

# %%
model.save("trafic.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
